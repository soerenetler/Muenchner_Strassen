# %%
import pandas as pd
import geopandas as gpd

# %%
adressen_df = pd.read_csv("raw_data/adressen_aktuell.txt")

# %%
adressen_df.head()
# Out:
#    STRASSE      STRANAM HSZ
# 0      900    Donaustr.  32
# 1     1733  Häusserstr.  21
# 2     2010    Hitzestr.   7
# 3     2010    Hitzestr.  11
# 4     2053     Höslstr.   5

# %%
adressen_count_df = adressen_df.groupby(["STRASSE"]).agg({"STRANAM": "first", "HSZ":"size"}).sort_values("HSZ",ascending=False)

# %%
adressen_count_df.head(10)
# Out:
#                      STRANAM  HSZ
# STRASSE
# 4166      Schleißheimer Str.  499
# 2690        Landsberger Str.  426
# 1129          Eversbuschstr.  364
# 1249     Forstenrieder Allee  359
# 797            Dachauer Str.  349
# 2781        Lerchenauer Str.  336
# 400                Balanstr.  335
# 4795        Truderinger Str.  324
# 1179      Feldmochinger Str.  321
# 612             Bodenseestr.  303

# %%
strassen_gdf = gpd.read_file("raw_data/ows.gml").set_crs("EPSG:25832", allow_override=True)

# %%
dissolved_adressen_gdf = strassen_gdf.dissolve(by="str_nr")["geometry"]

# %%
dissolved_adressen_gdf
# Out:
# str_nr
# 0.0        MULTILINESTRING ((696652.759 5338508.83, 69665...
# 1.0        LINESTRING (691774.732 5338190.733, 691767.155...
# 2.0        MULTILINESTRING ((697763.628 5338374.322, 6977...
# 3.0        LINESTRING (694347.125 5337278.02, 694356.554 ...
# 4.0        MULTILINESTRING ((687533.315 5339244.495, 6875...
#                                  ...
# 30033.0    LINESTRING (683389.744 5340635.2, 683470.635 5...
# 30035.0    LINESTRING (688742.093 5338715.906, 688735.475...
# 30043.0    MULTILINESTRING ((688684.503 5331097.516, 6887...
# 40008.0    LINESTRING (694628.642 5331151.454, 694621.737...
# 90004.0    LINESTRING (678085.163 5338372.419, 678078.847...
# Name: geometry, Length: 6143, dtype: geometry

# %%
combined_df = gpd.GeoDataFrame(adressen_count_df.join(dissolved_adressen_gdf, on="STRASSE"))

# %%
combined_df["laenge"] = combined_df.geometry.length

# %%
combined_df.sort_values("laenge", ascending=False).head(10)
# Out:
#                      STRANAM  HSZ  \
# STRASSE
# 797            Dachauer Str.  349
# 4166      Schleißheimer Str.  499
# 2690        Landsberger Str.  426
# 2694        Landshuter Allee  127
# 1376      Fürstenrieder Str.  280
# 4673     Tegernseer Landstr.  246
# 4505            Ständlerstr.   50
# 5669     Georg-Brauchle-Ring   26
# 294               Arnulfstr.  185
# 1413         Garmischer Str.   58
#
#                                                   geometry        laenge
# STRASSE
# 797      MULTILINESTRING ((690242.92 5336239.553, 69024...  19705.708937
# 4166     MULTILINESTRING ((690417.552 5342683.97, 69041...  14158.416756
# 2690     MULTILINESTRING ((687365.963 5335080.632, 6872...  13752.935779
# 2694     MULTILINESTRING ((688791.082 5339324.934, 6887...  13068.731376
# 1376     MULTILINESTRING ((686211.123 5335120.858, 6862...  11239.526237
# 4673     MULTILINESTRING ((693214.99 5329099.366, 69319...  10890.674817
# 4505     MULTILINESTRING ((696293.522 5331529.352, 6963...   9295.938996
# 5669     MULTILINESTRING ((688729.513 5339080.06, 68873...   8109.038751
# 294      MULTILINESTRING ((688125.269 5335768.855, 6881...   8047.039901
# 1413     MULTILINESTRING ((687571.028 5333192.342, 6875...   8044.212248

# %%
combined_df.sort_values("HSZ", ascending=False).head(10)
# Out:
#                      STRANAM  HSZ  \
# STRASSE
# 4166      Schleißheimer Str.  499
# 2690        Landsberger Str.  426
# 1129          Eversbuschstr.  364
# 1249     Forstenrieder Allee  359
# 797            Dachauer Str.  349
# 2781        Lerchenauer Str.  336
# 400                Balanstr.  335
# 4795        Truderinger Str.  324
# 1179      Feldmochinger Str.  321
# 612             Bodenseestr.  303
#
#                                                   geometry        laenge
# STRASSE
# 4166     MULTILINESTRING ((690417.552 5342683.97, 69041...  14158.416756
# 2690     MULTILINESTRING ((687365.963 5335080.632, 6872...  13752.935779
# 1129     MULTILINESTRING ((682656.262 5340961.143, 6826...   4010.817865
# 1249     MULTILINESTRING ((685937.268 5329422.612, 6859...   3294.989680
# 797      MULTILINESTRING ((690242.92 5336239.553, 69024...  19705.708937
# 2781     MULTILINESTRING ((689651.29 5340124.422, 68963...   7741.370127
# 400      MULTILINESTRING ((694468.173 5329438.678, 6944...   4805.549772
# 4795     MULTILINESTRING ((696783.426 5334246.731, 6967...   5116.521044
# 1179     MULTILINESTRING ((687831.235 5343287.463, 6878...   5008.575938
# 612      MULTILINESTRING ((681820.151 5335363.088, 6817...   3852.815418

# %%
import plotly.express as px
px.scatter(combined_df, x="laenge", y="HSZ", hover_data=["STRANAM"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/Daten_Projekte/Muenchener_Strassen/.venv/lib/python3.12/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/Documents/Daten_Projekte/Muenchener_Strassen/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/Documents/Daten_Projekte/Muenchener_Strassen/.venv/lib/python3.12/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'customdata': array([['Schleißheimer Str.'],
#                                    ['Landsberger Str.'],
#                                    ['Eversbuschstr.'],
#                                    ...,
#                                    ['Hans-Bieringer-Weg'],
#                                    ['Wiguläus-Hundt-Weg'],
#                                    ['Fritz-Neuland-Str.']], shape=(6301, 1), dtype=object),
#               'hovertemplate': 'laenge=%{x}<br>HSZ=%{y}<br>STRANAM=%{customdata[0]}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': {'bdata': ('gChEWDWny0DnipzHd9zKQDhoI7+iVa' ... 'BqWbpWQIOYI99EHFZAav0MhxnqREA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': ('8wGqAWwBZwFdAVABTwFEAUEBLwEYAR' ... 'EAAQABAAEAAQABAAEAAQABAAEAAQA='),
#                     'dtype': 'i2'},
#               'yaxis': 'y'}],
#     'layout': {'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'laenge'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'HSZ'}}}
# })

# %%
combined_df["adressen_pro_100meter"] = (combined_df["HSZ"] / combined_df["laenge"]) * 100

# %%
combined_df.sort_values("adressen_pro_100meter", ascending=False).head(10)
# Out:
#                        STRANAM  HSZ  \
# STRASSE
# 6021              Seiffertstr.   98
# 1950                Hertwigpl.   11
# 1470        Georg-Wopfner-Str.   40
# 6346             Karl-Breu-Weg   51
# 6050        Von-der-Vring-Str.   32
# 379         Bad-Kissingen-Str.   94
# 6003       Edmund-Husserl-Str.   24
# 6007     Martin-Heidegger-Str.   32
# 2732          Lechbrucker Str.   43
# 6448              Wildrosenweg   28
#
#                                                   geometry      laenge  \
# STRASSE
# 6021     LINESTRING (697855.331 5336044.186, 697856.359...  102.855332
# 1950     LINESTRING (683800.173 5340162.234, 683812.278...   14.515148
# 1470     MULTILINESTRING ((694135.514 5340649.076, 6941...   57.324496
# 6346     MULTILINESTRING ((697591.62 5334443.574, 69753...   89.624841
# 6050     LINESTRING (696950.368 5335529.519, 696911.475...   57.134013
# 379      MULTILINESTRING ((695725.1 5333039.303, 695722...  177.941721
# 6003     LINESTRING (681150.049 5337463.595, 681145.779...   49.088773
# 6007     LINESTRING (681120.931 5337412.566, 681147.555...   74.184674
# 2732     MULTILINESTRING ((685470.236 5329080.362, 6854...  112.861804
# 6448     LINESTRING (697039.235 5338656.093, 697113.647...   74.470842
#
#          adressen_pro_100meter
# STRASSE
# 6021                 95.279455
# 1950                 75.782899
# 1470                 69.778197
# 6346                 56.903866
# 6050                 56.008669
# 379                  52.826285
# 6003                 48.891016
# 6007                 43.135594
# 2732                 38.099692
# 6448                 37.598608

# %%
combined_df[combined_df["laenge"]>1000].sort_values("adressen_pro_100meter", ascending=False).head(10)
# Out:
#                      STRANAM  HSZ  \
# STRASSE
# 4244            Schrämelstr.  182
# 1869             Heilwigstr.  165
# 4212     Schneeglöckchenstr.  182
# 21            Adam-Berg-Str.  140
# 1123        Eulenspiegelstr.  147
# 2056            Hofangerstr.  231
# 5096         Wertheimer Str.  143
# 4800         Tsingtauer Str.  164
# 3434            Ottilienstr.  140
# 4434          Solalindenstr.  184
#
#                                                   geometry       laenge  \
# STRASSE
# 4244     MULTILINESTRING ((684010.811 5336973.765, 6839...  1127.702701
# 1869     MULTILINESTRING ((699657.546 5332457.12, 69964...  1110.732213
# 4212     MULTILINESTRING ((686514.612 5341521.656, 6863...  1281.530789
# 21       MULTILINESTRING ((695356.234 5331469.776, 6953...  1041.171727
# 1123     MULTILINESTRING ((698475.688 5328545.964, 6984...  1125.157163
# 2056     MULTILINESTRING ((695716.662 5332474.524, 6957...  1818.804397
# 5096     MULTILINESTRING ((680258.971 5336012.921, 6802...  1128.339223
# 4800     MULTILINESTRING ((699957.332 5330984.915, 6999...  1304.052773
# 3434     MULTILINESTRING ((699456.753 5332265.995, 6994...  1118.141294
# 4434     MULTILINESTRING ((699367.307 5332558.048, 6993...  1474.211244
#
#          adressen_pro_100meter
# STRASSE
# 4244                 16.139005
# 1869                 14.855066
# 4212                 14.201766
# 21                   13.446389
# 1123                 13.064842
# 2056                 12.700651
# 5096                 12.673494
# 4800                 12.576178
# 3434                 12.520779
# 4434                 12.481251

# %%
combined_df.sort_values("adressen_pro_100meter", ascending=True).head(20)
# Out:
#                             STRANAM  HSZ  \
# STRASSE
# 6251                  Max-Born-Str.    1
# 5811            Donnersbergerbrücke    1
# 6744            Heckenstallertunnel    1
# 6503            Hans-Steinkohl-Str.    1
# 2159                    Ifflandstr.    2
# 6461                 Isartalbahnweg    1
# 3501                 Pellegrinistr.    1
# 6661                   Weißenhofweg    1
# 5522                        Lippweg    1
# 5581             An der Schloßmauer    1
# 2212                       Isarring    4
# 6341                  Am Hüllgraben    1
# 2729                   Lebermoosweg    1
# 6683                   Menagerieweg    1
# 4524                   Stegmühlstr.    1
# 5508               Aubinger-Loh-Weg    1
# 5678                 Kusocinskidamm    1
# 1884            Heinrich-Mann-Allee    1
# 6731     Angela-von-den-Driesch-Weg    1
# 906                   Dornacher Weg    2
#
#                                                   geometry       laenge  \
# STRASSE
# 6251     MULTILINESTRING ((688062.513 5340226.578, 6880...  4588.017325
# 5811     MULTILINESTRING ((688578.056 5335621.092, 6885...  2746.062841
# 6744     MULTILINESTRING ((688626.022 5331682.119, 6886...  2564.726514
# 6503     MULTILINESTRING ((679290.222 5334304.147, 6792...  2216.864236
# 2159     MULTILINESTRING ((693572.308 5337098.187, 6935...  4395.818121
# 6461     MULTILINESTRING ((688929.016 5328563.95, 68891...  2039.671176
# 3501     MULTILINESTRING ((698019.037 5336700.277, 6980...  1822.632922
# 6661     MULTILINESTRING ((692473.755 5339443.664, 6924...  1731.102029
# 5522     MULTILINESTRING ((681830.351 5341956.979, 6818...  1705.413077
# 5581     MULTILINESTRING ((685539.398 5335811.373, 6855...  1656.842777
# 2212     MULTILINESTRING ((693131.381 5338292.358, 6931...  6432.176787
# 6341     MULTILINESTRING ((699920.653 5335140.61, 69993...  1478.269333
# 2729     MULTILINESTRING ((698492.31 5338495.32, 698602...  1429.416000
# 6683     MULTILINESTRING ((685555.203 5335675.276, 6855...  1425.295676
# 4524     MULTILINESTRING ((696685.052 5337775.303, 6967...  1337.753314
# 5508     MULTILINESTRING ((677585.664 5338082.986, 6778...  1287.181926
# 5678     MULTILINESTRING ((689239.107 5339762.172, 6892...  1270.776933
# 1884     MULTILINESTRING ((694022.712 5337355.776, 6940...  1256.208820
# 6731     MULTILINESTRING ((683979.032 5335720.961, 6839...  1251.359205
# 906      MULTILINESTRING ((698173.63 5336783.022, 69817...  2477.343249
#
#          adressen_pro_100meter
# STRASSE
# 6251                  0.021796
# 5811                  0.036416
# 6744                  0.038991
# 6503                  0.045109
# 2159                  0.045498
# 6461                  0.049028
# 3501                  0.054866
# 6661                  0.057767
# 5522                  0.058637
# 5581                  0.060356
# 2212                  0.062187
# 6341                  0.067647
# 2729                  0.069959
# 6683                  0.070161
# 4524                  0.074752
# 5508                  0.077689
# 5678                  0.078692
# 1884                  0.079605
# 6731                  0.079913
# 906                   0.080732

# %%
combined_df[combined_df["HSZ"]==1].sort_values("laenge", ascending=False).head(10)
# Out:
#                      STRANAM  HSZ  \
# STRASSE
# 6251           Max-Born-Str.    1
# 5811     Donnersbergerbrücke    1
# 6744     Heckenstallertunnel    1
# 6503     Hans-Steinkohl-Str.    1
# 6461          Isartalbahnweg    1
# 3501          Pellegrinistr.    1
# 6661            Weißenhofweg    1
# 5522                 Lippweg    1
# 5581      An der Schloßmauer    1
# 6341           Am Hüllgraben    1
#
#                                                   geometry       laenge  \
# STRASSE
# 6251     MULTILINESTRING ((688062.513 5340226.578, 6880...  4588.017325
# 5811     MULTILINESTRING ((688578.056 5335621.092, 6885...  2746.062841
# 6744     MULTILINESTRING ((688626.022 5331682.119, 6886...  2564.726514
# 6503     MULTILINESTRING ((679290.222 5334304.147, 6792...  2216.864236
# 6461     MULTILINESTRING ((688929.016 5328563.95, 68891...  2039.671176
# 3501     MULTILINESTRING ((698019.037 5336700.277, 6980...  1822.632922
# 6661     MULTILINESTRING ((692473.755 5339443.664, 6924...  1731.102029
# 5522     MULTILINESTRING ((681830.351 5341956.979, 6818...  1705.413077
# 5581     MULTILINESTRING ((685539.398 5335811.373, 6855...  1656.842777
# 6341     MULTILINESTRING ((699920.653 5335140.61, 69993...  1478.269333
#
#          adressen_pro_100meter
# STRASSE
# 6251                  0.021796
# 5811                  0.036416
# 6744                  0.038991
# 6503                  0.045109
# 6461                  0.049028
# 3501                  0.054866
# 6661                  0.057767
# 5522                  0.058637
# 5581                  0.060356
# 6341                  0.067647

# %%
combined_df[combined_df["STRANAM"]=="Dorfstr."]
# Out:
#           STRANAM  HSZ                                           geometry  \
# STRASSE
# 904      Dorfstr.   43  MULTILINESTRING ((683442.918 5337557.837, 6834...
#
#              laenge  adressen_pro_100meter
# STRASSE
# 904      918.415761               4.681975

# %%
combined_df[combined_df["STRANAM"]=="Platz der Opfer des Nationalsozialismus"]
# Out:
#                                          STRANAM  HSZ  \
# STRASSE
# 3617     Platz der Opfer des Nationalsozialismus    1
#
#                                                   geometry     laenge  \
# STRASSE
# 3617     LINESTRING (691424.709 5335350.029, 691438.69 ...  98.384249
#
#          adressen_pro_100meter
# STRASSE
# 3617                  1.016423

# %%
bezrike_gdf =gpd.read_file("processed_data/muenchen_stadtbezirke.geojson")
sjoined_gdf = combined_df.sjoin(bezrike_gdf, how="left", predicate="intersects")
sjoined_gdf.head()
# Out:
#                     STRANAM  HSZ  \
# STRASSE
# 4166     Schleißheimer Str.  499
# 4166     Schleißheimer Str.  499
# 4166     Schleißheimer Str.  499
# 4166     Schleißheimer Str.  499
# 2690       Landsberger Str.  426
#
#                                                   geometry        laenge  \
# STRASSE
# 4166     MULTILINESTRING ((690417.552 5342683.97, 69041...  14158.416756
# 4166     MULTILINESTRING ((690417.552 5342683.97, 69041...  14158.416756
# 4166     MULTILINESTRING ((690417.552 5342683.97, 69041...  14158.416756
# 4166     MULTILINESTRING ((690417.552 5342683.97, 69041...  14158.416756
# 2690     MULTILINESTRING ((687365.963 5335080.632, 6872...  13752.935779
#
#          adressen_pro_100meter  index_right sb_nummer  \
# STRASSE
# 4166                  3.524405          2.0        03
# 4166                  3.524405          3.0        04
# 4166                  3.524405         10.0        11
# 4166                  3.524405         23.0        24
# 2690                  3.097520          1.0        02
#
#                               sb_name
# STRASSE
# 4166                      Maxvorstadt
# 4166                   Schwabing-West
# 4166            Milbertshofen-Am Hart
# 4166           Feldmoching-Hasenbergl
# 2690     Ludwigsvorstadt-Isarvorstadt

# %%
sjoined_gdf.groupby("sb_name").size().sort_values(ascending=False)
# Out:
# sb_name
# Bogenhausen                                               466
# Thalkirchen-Obersendling-Forstenried-Fürstenried-Solln    448
# Ramersdorf-Perlach                                        446
# Pasing-Obermenzing                                        441
# Trudering-Riem                                            407
# Schwabing-Freimann                                        392
# Aubing-Lochhausen-Langwied                                345
# Neuhausen-Nymphenburg                                     320
# Untergiesing-Harlaching                                   288
# Feldmoching-Hasenbergl                                    271
# Allach-Untermenzing                                       270
# Sendling-Westpark                                         243
# Milbertshofen-Am Hart                                     228
# Moosach                                                   216
# Hadern                                                    212
# Altstadt-Lehel                                            209
# Laim                                                      189
# Au-Haidhausen                                             176
# Obergiesing-Fasangarten                                   167
# Berg am Laim                                              167
# Schwabing-West                                            149
# Ludwigsvorstadt-Isarvorstadt                              144
# Maxvorstadt                                               126
# Sendling                                                  111
# Schwanthalerhöhe                                           56
# dtype: int64

# %%
sjoined_gdf.groupby(level=0).agg({"sb_name": "size", "STRANAM": "first"}).sort_values("sb_name", ascending=False)
# Out:
#          sb_name             STRANAM
# STRASSE
# 797            5       Dachauer Str.
# 1376           4  Fürstenrieder Str.
# 2690           4    Landsberger Str.
# 4166           4  Schleißheimer Str.
# 1455           3         Georgenstr.
# ...          ...                 ...
# 2359           1    Karl-Schurz-Str.
# 2358           1   Karl-Schmolz-Str.
# 2357           1    Karlsburger Str.
# 2356           1       Karlsbergstr.
# 6822           1  Fritz-Neuland-Str.
#
# [6301 rows x 2 columns]

# %%
sjoined_gdf.groupby(level=0).size().sort_values(ascending=False).plot(kind="hist", bins=5, backend='plotly')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/Daten_Projekte/Muenchener_Strassen/.venv/lib/python3.12/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/Documents/Daten_Projekte/Muenchener_Strassen/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/Documents/Daten_Projekte/Muenchener_Strassen/.venv/lib/python3.12/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'bingroup': 'x',
#               'hovertemplate': 'variable=0<br>value=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': '0',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': '0',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'histogram',
#               'x': {'bdata': ('BQQEBAMDAwMDAwMDAwMDAwMDAwMDAw' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQ=='),
#                     'dtype': 'i1'},
#               'xaxis': 'x',
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'legend': {'title': {'text': 'variable'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'value'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'count'}}}
# })

# %%
combined_df.groupby("STRANAM").size().sort_values(ascending=True).head(10)
# Out:
# STRANAM
# ALEXANDER-MIKLÓSY-W.    1
# Pasinger Heuweg         1
# Pasinger Bahnhofspl.    1
# Pasettiweg              1
# Paschstr.               1
# Parzivalstr.            1
# Parzivalpl.             1
# Partnachstr.            1
# Partnachpl.             1
# Partenkirchner Str.     1
# dtype: int64

# %%
combined_df[combined_df["STRANAM"].str.contains("roß")]
# Out:
#                            STRANAM  HSZ  \
# STRASSE
# 1649     Großfriedrichsburger Str.   94
# 1652             Großhaderner Str.   84
# 1656             Großvenedigerstr.   46
# 1653           Großhesseloher Str.   27
# 1655               Groß-Nabas-Str.   18
# 1648                Großbeerenstr.   15
# 1654                    Großlappen    1
#
#                                                   geometry      laenge  \
# STRASSE
# 1649     MULTILINESTRING ((701521.819 5332681.119, 7015...  631.043576
# 1652     MULTILINESTRING ((684514.355 5332098.498, 6845...  911.347119
# 1656     MULTILINESTRING ((696425.481 5332997.444, 6964...  410.624135
# 1653     MULTILINESTRING ((688563.006 5328547.026, 6885...  470.748519
# 1655     LINESTRING (701477.962 5331961.521, 701483.262...  209.834942
# 1648     LINESTRING (686346.2 5339265.284, 686451.264 5...  124.810788
# 1654                                                  None         NaN
#
#          adressen_pro_100meter
# STRASSE
# 1649                 14.895960
# 1652                  9.217125
# 1656                 11.202459
# 1653                  5.735546
# 1655                  8.578171
# 1648                 12.018192
# 1654                       NaN

# %%
combined_df.to_file("processed_data/strassen_adressen_muenchen.geojson")

# %%
gdf_wgs84 = combined_df.to_crs(epsg=4326)
gdf_wgs84.to_file("processed_data/strassen_adressen_muenchen_wgs84.geojson", driver="GeoJSON")
